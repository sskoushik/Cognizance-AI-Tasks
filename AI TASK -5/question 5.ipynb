# %% [markdown]
# # Lasso Regression

# %%
# %matplotlib inline
import re
import random
import pandas as pd
import numpy as np
import csv as csv
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import classification_report
from statsmodels.graphics import mosaicplot
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import confusion_matrix

# %%
# !pip install keras
# !pip install fancyimpute
# Out:
# Collecting keras
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 333.1 kB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.9.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting knnimpute>=0.1.0
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from fancyimpute) (1.1.1)
# Collecting cvxpy
#   Downloading cvxpy-1.2.1-cp310-cp310-win_amd64.whl (833 kB)
#      ------------------------------------ 833.2/833.2 kB 542.9 kB/s eta 0:00:00
# Collecting cvxopt
#   Downloading cvxopt-1.3.0-cp310-cp310-win_amd64.whl (12.7 MB)
#      -------------------------------------- 12.7/12.7 MB 380.5 kB/s eta 0:00:00
# Collecting pytest
#   Downloading pytest-7.1.2-py3-none-any.whl (297 kB)
#      ------------------------------------ 297.0/297.0 kB 510.3 kB/s eta 0:00:00
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      ------------------------------------ 154.7/154.7 kB 578.0 kB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.23.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (3.1.0)
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post5-cp310-cp310-win_amd64.whl (278 kB)
#      ------------------------------------ 278.5/278.5 kB 206.8 kB/s eta 0:00:00
# Collecting scs>=1.1.6
#   Downloading scs-3.2.0-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 478.0 kB/s eta 0:00:00
# Collecting ecos>=2
#   Downloading ecos-2.0.10-cp310-cp310-win_amd64.whl (68 kB)
#      -------------------------------------- 68.5/68.5 kB 925.3 kB/s eta 0:00:00
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from pytest->fancyimpute) (0.4.5)
# Requirement already satisfied: packaging in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from pytest->fancyimpute) (21.3)
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.1.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      -------------------------------------- 98.7/98.7 kB 257.2 kB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from pytest->fancyimpute) (21.4.0)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting qdldl
#   Downloading qdldl-0.1.5.post2-cp310-cp310-win_amd64.whl (83 kB)
#      -------------------------------------- 83.8/83.8 kB 156.8 kB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sskou\appdata\local\programs\python\python310\lib\site-packages (from packaging->pytest->fancyimpute) (3.0.9)
# Using legacy 'setup.py install' for fancyimpute, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for knnimpute, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for atomicwrites, since package 'wheel' is not installed.
# Installing collected packages: nose, iniconfig, tomli, py, pluggy, knnimpute, cvxopt, atomicwrites, scs, qdldl, pytest, ecos, osqp, cvxpy, fancyimpute
#   Running setup.py install for knnimpute: started
#   Running setup.py install for knnimpute: finished with status 'done'
#   Running setup.py install for atomicwrites: started
#   Running setup.py install for atomicwrites: finished with status 'done'
#   Running setup.py install for fancyimpute: started
#   Running setup.py install for fancyimpute: finished with status 'done'
# Successfully installed atomicwrites-1.4.1 cvxopt-1.3.0 cvxpy-1.2.1 ecos-2.0.10 fancyimpute-0.7.0 iniconfig-1.1.1 knnimpute-0.1.0 nose-1.3.7 osqp-0.6.2.post5 pluggy-1.0.0 py-1.11.0 pytest-7.1.2 qdldl-0.1.5.post2 scs-3.2.0 tomli-2.0.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fancyimpute 

random.seed(100)
np.random.seed(5)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
matplotlib.style.use('ggplot')

# %%
train = pd.read_csv(r"C:\Users\sskou\OneDrive\Pictures\train.csv", header=0)
test = pd.read_csv(r"C:\Users\sskou\OneDrive\Pictures\test1.csv", header=0)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex    Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                             Heikkinen, Miss. Laina  female 26.000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                           Allen, Mr. William Henry    male 35.000      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171  7.250   NaN        S
# 1      0          PC 17599 71.283   C85        C
# 2      0  STON/O2. 3101282  7.925   NaN        S
# 3      0            113803 53.100  C123        S
# 4      0            373450  8.050   NaN        S

# %%
train.describe()
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count      891.000   891.000 891.000 714.000 891.000 891.000 891.000
# mean       446.000     0.384   2.309  29.699   0.523   0.382  32.204
# std        257.354     0.487   0.836  14.526   1.103   0.806  49.693
# min          1.000     0.000   1.000   0.420   0.000   0.000   0.000
# 25%        223.500     0.000   2.000  20.125   0.000   0.000   7.910
# 50%        446.000     0.000   3.000  28.000   0.000   0.000  14.454
# 75%        668.500     1.000   3.000  38.000   1.000   0.000  31.000
# max        891.000     1.000   3.000  80.000   8.000   6.000 512.329

# %%
pd.crosstab(train.Survived, train.Sex)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(train.Survived, train.Sex, normalize=True)
# Out:
# Sex       female  male
# Survived
# 0          0.091 0.525
# 1          0.262 0.122

# %%
g = sns.catplot(x='Age', y='PassengerId', hue='Survived', col='Sex', kind='strip', data=train);
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=20))
plt.show()

# %%
sns.catplot(x="Embarked", y="PassengerId", hue="Survived", col="Pclass", kind="strip", data=train);

# %%
sns.catplot(x="Embarked", y="PassengerId", hue="Survived", col="Pclass", kind="strip", data=train);

# %%
survived = train['Survived']
test['Survived'] = 0
all_titanic = train.append(test, ignore_index=True)
# Out:
# C:\Users\sskou\AppData\Local\Temp\ipykernel_29936\4204326707.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_titanic = train.append(test, ignore_index=True)

# %%
df = pd.read_csv(r"C:\Users\sskou\OneDrive\Pictures\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male 27.000      0
# 887                       Graham, Miss. Margaret Edith  female 19.000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.000      0
# 890                                Dooley, Mr. Patrick    male 32.000      0
#
#      Parch            Ticket   Fare Cabin Embarked
# 0        0         A/5 21171  7.250   NaN        S
# 1        0          PC 17599 71.283   C85        C
# 2        0  STON/O2. 3101282  7.925   NaN        S
# 3        0            113803 53.100  C123        S
# 4        0            373450  8.050   NaN        S
# ..     ...               ...    ...   ...      ...
# 886      0            211536 13.000   NaN        S
# 887      0            112053 30.000   B42        S
# 888      2        W./C. 6607 23.450   NaN        S
# 889      0            111369 30.000  C148        C
# 890      0            370376  7.750   NaN        Q
#
# [891 rows x 12 columns]

# %%
def create_titles(names):
    return [re.split(', |\. ', name)[1] for name in all_titanic.Name]
    
def title_dist():
    unique_titles = all_titanic['Title'].unique()
    n_passengers = [sum(all_titanic['Title'] == title) for title in unique_titles]
    age_missing = [sum((all_titanic['Title'] == title) & (pd.isnull(all_titanic['Age']))) for title in unique_titles]
    min_age = [min(all_titanic.loc[all_titanic['Title'] == title, 'Age']) for title in unique_titles]
    max_age = [max(all_titanic.loc[all_titanic['Title'] == title, 'Age']) for title in unique_titles]

    title_dist = pd.DataFrame({'Title': unique_titles, 'NumPassengers': n_passengers, 'AgeMissing': age_missing, 'MinAge': min_age, 'MaxAge': max_age})
    title_dist.columns.tolist()

    return(title_dist[['Title', 'NumPassengers', 'AgeMissing', 'MinAge', 'MaxAge']])

all_titanic['Title'] = create_titles(all_titanic.Name)
title_dist()
# Out:
#            Title  NumPassengers  AgeMissing  MinAge  MaxAge
# 0             Mr            757         176  11.000  80.000
# 1            Mrs            197          27  14.000  76.000
# 2           Miss            260          50   0.170  63.000
# 3         Master             61           8   0.330  14.500
# 4            Don              1           0  40.000  40.000
# 5            Rev              8           0  27.000  57.000
# 6             Dr              8           1  23.000  54.000
# 7            Mme              1           0  24.000  24.000
# 8             Ms              2           1  28.000  28.000
# 9          Major              2           0  45.000  52.000
# 10          Lady              1           0  48.000  48.000
# 11           Sir              1           0  49.000  49.000
# 12          Mlle              2           0  24.000  24.000
# 13           Col              4           0  47.000  60.000
# 14          Capt              1           0  70.000  70.000
# 15  the Countess              1           0  33.000  33.000
# 16      Jonkheer              1           0  38.000  38.000
# 17          Dona              1           0  39.000  39.000

# %%
def condense_titles(df):
    df.loc[(df['Title'] == 'Mr') & 
        (df['Age'] <= 14.5) & 
        (pd.notnull(df['Age'])), 'Title'] = 'Master'

    df.loc[(df['Title'] == 'Capt') |
            (df['Title'] == 'Col') |
            (df['Title'] == 'Don') |
            (df['Title'] == 'Major') |
            (df['Title'] == 'Rev') |
            (df['Title'] == 'Jonkheer') |
            (df['Title'] == 'Sir'), 'Title'] = 'Mr'

    df.loc[(df['Title'] == 'Dona') |
            (df['Title'] == 'Mlle') |
            (df['Title'] == 'Mme'), 'Title'] = 'Ms'

    df.loc[(df['Title'] == 'Lady') | (df['Title'] == 'the Countess'), 'Title'] = 'Mrs'

    df.loc[(df['Title'] == 'Dr') & (df['Sex'] == 'female'), 'Title'] = 'Ms'
    df.loc[(df['Title'] == 'Dr') & (df['Sex'] == 'male'), 'Title'] = 'Mr'
    
    return(df)

all_titanic = condense_titles(all_titanic)

# %%
title_dist()
# Out:
#     Title  NumPassengers  AgeMissing  MinAge  MaxAge
# 0      Mr            777         177  15.000  80.000
# 1     Mrs            199          27  14.000  76.000
# 2    Miss            260          50   0.170  63.000
# 3  Master             66           8   0.330  14.500
# 4      Ms              7           1  24.000  49.000

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
all_titanic['FamilySize'] = (all_titanic['SibSp'] + all_titanic['Parch']) <= 3
all_titanic['FamilySize'] = all_titanic['FamilySize'].astype(int)

# %%
all_titanic['Mother'] = (all_titanic['Title'] == 'Mrs') & (all_titanic['Parch'] > 0)
all_titanic['Mother'] = all_titanic['Mother'].astype(int)

# %%
all_titanic['Single'] = all_titanic['SibSp'] + all_titanic['Parch'] + 1 == 1
all_titanic['Single'] = all_titanic['Single'].astype(int)

# %%
all_titanic['FamilyName'] = [re.split(', ', name)[0] for name in all_titanic['Name']]

# %%
family_ticket = all_titanic.loc[all_titanic['Single'] == 0, ['FamilyName', 'Ticket']]
family_ticket = family_ticket.sort_values('FamilyName')
family_ticket.head()
# Out:
#      FamilyName     Ticket
# 746      Abbott  C.A. 2673
# 1283     Abbott  C.A. 2673
# 279      Abbott  C.A. 2673
# 874     Abelson  P/PP 3381
# 308     Abelson  P/PP 3381

# %%
last_digits = [ticket[-3:] for ticket in all_titanic['Ticket']]
all_titanic['FamilyName'] = all_titanic['FamilyName'] + last_digits

# %%
all_titanic['FamilySurvived'] = 0
families = all_titanic.loc[all_titanic['Parch'] + all_titanic['SibSp'] > 0, ]

by_family_name = families.groupby(['FamilyName'])
family_name_survived = by_family_name['Survived'].sum()

# %%
family_name_survived = family_name_survived[family_name_survived > 0]
survived_names = family_name_survived.index.values
all_titanic.loc[all_titanic['FamilyName'].isin(survived_names), 'FamilySurvived'] = 1

# %%
all_titanic['AgeClass'] = 0
all_titanic.loc[all_titanic['Age'] <= 10, 'AgeClass'] = 1
all_titanic.loc[(all_titanic['Age'] > 10) & (all_titanic['Age'] <= 20), 'AgeClass'] = 2
all_titanic.loc[(all_titanic['Age'] > 20) & (all_titanic['Age'] <= 35), 'AgeClass'] = 3
all_titanic.loc[all_titanic['Age'] >= 35, 'AgeClass'] = 4

# %%
cols = [col for col in all_titanic.columns if col not in ['Survived', 'Name', 'PassengerId', 'Ticket', 'AgeClass']]
all_titanic[cols].isnull().sum()
# Out:
# Pclass               0
# Sex                  0
# Age                263
# SibSp                0
# Parch                0
# Fare                 1
# Cabin             1014
# Embarked             2
# Title                0
# FamilySize           0
# Mother               0
# Single               0
# FamilyName           0
# FamilySurvived       0
# dtype: int64

# %%
all_titanic.loc[pd.isnull(all_titanic['Embarked']), 'Embarked'] = 'S'

# %%
ports = pd.get_dummies(all_titanic['Embarked'])
titles = pd.get_dummies(all_titanic['Title'])

all_titanic = pd.concat([all_titanic, ports, titles], axis = 1)
all_titanic = all_titanic.drop(['Embarked', 'Title'], axis = 1)

# %%
features = ['Pclass', 'SibSp', 'Parch', 'C', 'Q', 'S', 'Master', 'Miss', 'Mr', 'Mrs', 'Ms']

all_fares = all_titanic.loc[pd.notnull(all_titanic['Fare'])]
missing_fare = all_titanic.loc[pd.isnull(all_titanic['Fare'])]

clf = DecisionTreeRegressor(random_state=0)

X = all_fares[features]
y = all_fares['Fare']
clf.fit(X, y)

# # Predict fare based on this
all_titanic.loc[pd.isnull(all_titanic['Fare']), 'Fare']
# Out:
# 1043   NaN
# Name: Fare, dtype: float64

# %%
pd.crosstab(pd.isnull(all_titanic['Age']), all_titanic.Pclass)
# Out:
# Pclass    1    2    3
# Age
# False   284  261  501
# True     39   16  208

# %%
from fancyimpute import IterativeImputer as MICE
df = pd.read_csv(r"C:\Users\sskou\OneDrive\Pictures\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male 27.000      0
# 887                       Graham, Miss. Margaret Edith  female 19.000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.000      0
# 890                                Dooley, Mr. Patrick    male 32.000      0
#
#      Parch            Ticket   Fare Cabin Embarked
# 0        0         A/5 21171  7.250   NaN        S
# 1        0          PC 17599 71.283   C85        C
# 2        0  STON/O2. 3101282  7.925   NaN        S
# 3        0            113803 53.100  C123        S
# 4        0            373450  8.050   NaN        S
# ..     ...               ...    ...   ...      ...
# 886      0            211536 13.000   NaN        S
# 887      0            112053 30.000   B42        S
# 888      2        W./C. 6607 23.450   NaN        S
# 889      0            111369 30.000  C148        C
# 890      0            370376  7.750   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
def impute_missing_age(columns):
    age = columns[0]
    passenger_class = columns[1]
    if pd.isnull(age):
        if(passenger_class == 1):
            return df[df['Pclass'] == 1]['Age'].mean()
        elif(passenger_class == 2):
            return df[df['Pclass'] == 2]['Age'].mean()
        elif(passenger_class == 3):
            return df[df['Pclass'] == 3]['Age'].mean()
    else:
        return age

# %%
df['Age'] = df[['Age', 'Pclass']].apply(impute_missing_age, axis = 1)

# %%
df.drop('Cabin', axis=1, inplace = True)
df.dropna(inplace = True)

sex_data = pd.get_dummies(df['Sex'], drop_first = True)
embarked_data = pd.get_dummies(df['Embarked'], drop_first = True)

df = pd.concat([df, sex_data, embarked_data], axis = 1)

df.drop(['Name', 'PassengerId', 'Ticket', 'Sex', 'Embarked'], axis = 1, inplace = True)

df.head()
# Out:
#    Survived  Pclass    Age  SibSp  Parch   Fare  male  Q  S
# 0         0       3 22.000      1      0  7.250     1  0  1
# 1         1       1 38.000      1      0 71.283     0  0  0
# 2         1       3 26.000      0      0  7.925     0  0  1
# 3         1       1 35.000      1      0 53.100     0  0  1
# 4         0       3 35.000      0      0  8.050     1  0  1

# %%
y_data = df['Survived']
x_data = df.drop('Survived', axis = 1)

x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x_data, y_data, test_size = 0.3)

# %%
lasso = Lasso(alpha = 1)
lasso.fit(x_training_data, y_training_data)
y_pred = lasso.predict(x_test_data)

mean_squared_error = np.mean((y_pred - y_test_data)**2)
print("Mean squared error on test set", mean_squared_error)
lasso_coeff = pd.DataFrame()
lasso_coeff["Columns"] = x_training_data.columns
lasso_coeff['Coefficient Estimate'] = pd.Series(lasso.coef_)
  
print(lasso_coeff)
# Out:
# Mean squared error on test set 0.2317432196851437
#   Columns  Coefficient Estimate
# 0  Pclass                -0.000
# 1     Age                -0.000
# 2   SibSp                -0.000
# 3   Parch                 0.000
# 4    Fare                 0.002
# 5    male                -0.000
# 6       Q                 0.000
# 7       S                -0.000

# %%
fig, ax = plt.subplots(figsize =(20, 10))

color =['tab:gray', 'tab:blue', 'tab:orange',
'tab:green', 'tab:blue', 'tab:purple', 'tab:brown',
'tab:red', 'tab:gray', 'tab:olive', 'tab:cyan',
'tab:orange', 'tab:green', 'tab:blue', 'tab:olive']

ax.bar(lasso_coeff["Columns"],
lasso_coeff['Coefficient Estimate'],color = color)

ax.spines['bottom'].set_position('zero')

plt.style.use('ggplot')
plt.show()

# %%
lasso.score(x_test_data, y_test_data)
# Out:
# 0.04071870931748878
